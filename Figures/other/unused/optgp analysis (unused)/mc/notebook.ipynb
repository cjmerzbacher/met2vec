# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_mc_df(path : str):
    return 

mc3_dfs = {
    100 :   pd.read_csv("./mean_classifier_alivhep_k100_3runs.csv"),
    250 :   pd.read_csv("./mean_classifier_alivhep_k250_3runs.csv"),
    500 :   pd.read_csv("./mean_classifier_alivhep_k500_3runs.csv"),
    1000 : pd.read_csv("./mean_classifier_alivhep_k1000_3runs.csv"),
    2500 : pd.read_csv("./mean_classifier_alivhep_k2500_3runs.csv"),
    5000 : pd.read_csv("./mean_classifier_alivhep_k5000_3runs.csv"),
}

mc6_dfs = {
    #100 :   pd.read_csv("./mean_classifier_alivhep_k100_6runs.csv"),
    #250 :   pd.read_csv("./mean_classifier_alivhep_k250_6runs.csv"),
    #500 :   pd.read_csv("./mean_classifier_alivhep_k500_6runs.csv"),
    1000 : pd.read_csv("./mean_classifier_alivhep_k1000_6runs.csv"),
    2500 : pd.read_csv("./mean_classifier_alivhep_k2500_6runs.csv"),
    5000 : pd.read_csv("./mean_classifier_alivhep_k5000_6runs.csv"),
}



mc3_dfs[100]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 16
#       2     return
#       4 mc3_dfs = {
#       5     100 :   pd.read_csv("./mean_classifier_alivhep_k100_3runs.csv"),
#       6     250 :   pd.read_csv("./mean_classifier_alivhep_k250_3runs.csv"),
#    (...)
#      10     5000 : pd.read_csv("./mean_classifier_alivhep_k5000_3runs.csv"),
#      11 }
#      13 mc6_dfs = {
#      14     #100 :   pd.read_csv("./mean_classifier_alivhep_k100_6runs.csv"),
#      15     #250 :   pd.read_csv("./mean_classifier_alivhep_k250_6runs.csv"),
# ---> 16     500 :   pd.read_csv("./mean_classifier_alivhep_k500_6runs.csv"),
#      17     1000 : pd.read_csv("./mean_classifier_alivhep_k1000_6runs.csv"),
#      18     2500 : pd.read_csv("./mean_classifier_alivhep_k2500_6runs.csv"),
#      19     5000 : pd.read_csv("./mean_classifier_alivhep_k5000_6runs.csv"),
#      20 }
# ...

# %%
fig, axs = plt.subplots(1, len(mc3_dfs), figsize=(16, 4))

for i, (k, mc_df) in enumerate(mc3_dfs.items()):
    axs[i].imshow(mc_df.drop(columns="test_file_n").values)
    axs[i].set_title(f"$k={k}$")
    axs[i].axis("off")

fig.suptitle("MC Accuracies classifying 3 runs with different $k$", fontsize=16)
# Out:
# Text(0.5, 0.98, 'MC Accuracies classifying 3 runs with different $k$')

# %%
fig, axs = plt.subplots(1, len(mc6_dfs), figsize=(16, 4))

for i, (k, mc_df) in enumerate(mc6_dfs.items()):
    axs[i].imshow(mc_df.drop(columns="test_file_n").values)
    axs[i].set_title(f"$k={k}$")
    axs[i].axis("off")

fig.suptitle("MC Accuracies classifying 3 runs with different $k$", fontsize=16)
# Out:
# Text(0.5, 0.98, 'MC Accuracies classifying 3 runs with different $k$')
