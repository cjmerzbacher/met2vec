# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Test

# %%
data = pd.read_csv("../data/plot_data/test.csv")
data
# Out:
#    skeletal_muscle_myocytes  liver_hepatocytes  lung_macrophages  \
# 0                      0.32               0.33              0.35
#
#           test_label
# 0  liver_hepatocytes

# %%
unl_data = data.drop(columns='test_label')

# %%
im = plt.imshow(unl_data, vmin=0, vmax=1)
plt.colorbar(im, label='Accuracy', shrink=0.35, aspect=5)
plt.xticks([0,1,2], unl_data.columns, rotation=45)
plt.yticks(list(range(len(data))), data['test_label'])
# Out:
# ([<matplotlib.axis.YTick at 0x1ce30f46210>], [Text(0, 0, 'liver_hepatocytes')])

# %% [markdown]
# # Human Cells (Reduced Agren Dataset), Agren Dataset as test

# %%
df_hc_agren = pd.read_csv('..\\data\\plot_data\\villarica\\gmm\\gmm_emb64_inner_hc_agren.csv')
df_hc_agren
# Out:
#     lateral ventricle - glial cells  breast - glandular cells  \
# 0                          0.032143                  0.000000
# 1                          0.069048                  0.000000
# 2                          0.061905                  0.002381
# 3                          0.023810                  0.183333
# 4                          0.105952                  0.072619
# ..                              ...                       ...
# 73                         0.111905                  0.001190
# 74                         0.489286                  0.003571
# 75                         0.036905                  0.026190
# 76                         0.048810                  0.115476
# 77                         0.000000                  0.000000
#
#     hippocampus - glial cells  breast - adipocytes  \
# 0                    0.023810             0.058333
# 1                    0.019048             0.161905
# 2                    0.154762             0.275000
# 3                    0.086905             0.077381
# 4                    0.183333             0.064286
# ..                        ...                  ...
# 73                   0.135714             0.160714
# 74                   0.034524             0.075000
# 75                   0.014286             0.051190
# 76                   0.027381             0.122619
# 77                   0.091667             0.153571
#
#     epididymis - glandular cells  skeletal_muscle_myocytes  \
# 0                       0.016667                  0.008333
# 1                       0.003571                  0.000000
# 2                       0.002381                  0.009524
# 3                       0.000000                  0.000000
# 4                       0.000000                  0.000000
# ..                           ...                       ...
# 73                      0.000000                  0.025000
# 74                      0.004762                  0.002381
# 75                      0.009524                  0.015476
# 76                      0.000000                  0.000000
# 77                      0.000000                  0.014286
#
#     colon - glandular cells  cerebral cortex - glial cells  \
# 0                  0.000000                       0.000000
# 1                  0.000000                       0.017857
# 2                  0.010714                       0.000000
# 3                  0.000000                       0.013095
# 4                  0.000000                       0.000000
# ..                      ...                            ...
# 73                 0.007143                       0.003571
# 74                 0.000000                       0.000000
# 75                 0.000000                       0.000000
# 76                 0.000000                       0.000000
# 77                 0.000000                       0.000000
#
#     appendix - lymphoid tissue  heart muscle - myocytes  ...  \
# 0                     0.142857                 0.000000  ...
# 1                     0.000000                 0.009524  ...
# 2                     0.030952                 0.000000  ...
# 3                     0.000000                 0.001190  ...
# 4                     0.000000                 0.000000  ...
# ..                         ...                      ...  ...
# 73                    0.001190                 0.004762  ...
# 74                    0.001190                 0.000000  ...
# 75                    0.084524                 0.000000  ...
# 76                    0.000000                 0.007143  ...
# 77                    0.169048                 0.000000  ...
#
#     cervix, uterine - squamous epithelial cells  \
# 0                                      0.253571
# 1                                      0.032143
# 2                                      0.034524
# 3                                      0.000000
# 4                                      0.090476
# ..                                          ...
# 73                                     0.044048
# 74                                     0.045238
# 75                                     0.011905
# 76                                     0.016667
# 77                                     0.189286
#
#     adrenal gland - glandular cells  cervix, uterine - glandular cells  \
# 0                          0.000000                           0.000000
# 1                          0.003571                           0.000000
# 2                          0.000000                           0.026190
# 3                          0.000000                           0.001190
# 4                          0.000000                           0.000000
# ..                              ...                                ...
# 73                         0.000000                           0.000000
# 74                         0.000000                           0.000000
# 75                         0.000000                           0.007143
# 76                         0.000000                           0.004762
# 77                         0.071429                           0.000000
#
#     kidney - cells in glomeruli  fallopian tube - glandular cells  \
# 0                      0.011905                          0.000000
# 1                      0.078571                          0.000000
# 2                      0.088095                          0.004762
# 3                      0.002381                          0.016667
# 4                      0.004762                          0.000000
# ..                          ...                               ...
# 73                     0.003571                          0.010714
# 74                     0.002381                          0.039286
# 75                     0.005952                          0.242857
# 76                     0.000000                          0.005952
# 77                     0.146429                          0.000000
#
#     lung_macrophages  hippocampus - neuronal cells  \
# 0           0.001190                      0.001190
# 1           0.160714                      0.001190
# 2           0.000000                      0.000000
# 3           0.014286                      0.001190
# 4           0.092857                      0.034524
# ..               ...                           ...
# 73          0.032143                      0.009524
# 74          0.002381                      0.000000
# 75          0.000000                      0.016667
# 76          0.001190                      0.000000
# 77          0.001190                      0.020238
#
#     cerebral cortex - neuronal cells  liver_hepatocytes  \
# 0                                0.0            0.00000
# 1                                0.0            0.00000
# 2                                0.0            0.00000
# 3                                0.0            0.00000
# 4                                0.0            0.00000
# ..                               ...                ...
# 73                               0.0            0.00000
# 74                               0.0            0.00000
# 75                               0.0            0.00000
# 76                               0.0            0.00000
# 77                               0.0            0.00119
#
#                                        test_label
# 0                tonsil_-_germinal_center_cells_2
# 1                    spleen_-_cells_in_red_pulp_2
# 2       bronchus_-_respiratory_epithelial_cells_2
# 3                            lung_-_pneumocytes_2
# 4              fallopian_tube_-_glandular_cells_2
# ..                                            ...
# 73           urinary_bladder_-_urothelial_cells_2
# 74  cervix,_uterine_-_squamous_epithelial_cells_2
# 75                  kidney_-_cells_in_glomeruli_2
# 76                   duodenum_-_glandular_cells_2
# 77           tonsil_-_squamous_epithelial_cells_2
#
# [78 rows x 33 columns]

# %%
df_hc_agren_unl = df_hc_agren.drop(columns='test_label')

# %%
fig, ax = plt.subplots(1,1, figsize=(18,18))

im = ax.imshow(df_hc_agren_unl, vmin=0, vmax=1)
plt.colorbar(im, label='Prediction Rate')

xlocs = range(df_hc_agren_unl.values.shape[1])
ylocs = range(len(df_hc_agren))

yticks = map(lambda s: s.replace('_', ' ').replace('2', ''), df_hc_agren['test_label'])

ax.set_xticks(xlocs, df_hc_agren_unl.columns, rotation=90)
ax.set_yticks(ylocs, yticks)

plt.show()
