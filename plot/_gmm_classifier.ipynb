# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Test

# %%
data = pd.read_csv("../data/plot_data/test.csv")
data
# Out:
#          tsne0      tsne1                     label
# 0   -28.559916  -4.105885         liver_hepatocytes
# 1   -28.551674  -4.067074         liver_hepatocytes
# 2   -28.541235  -4.114550         liver_hepatocytes
# 3   -28.564644  -3.820658         liver_hepatocytes
# 4   -28.545006  -3.806225         liver_hepatocytes
# ..         ...        ...                       ...
# 295  -1.301498 -22.366507  skeletal_muscle_myocytes
# 296  -1.168200 -22.349525  skeletal_muscle_myocytes
# 297  -1.002921 -22.356998  skeletal_muscle_myocytes
# 298  -0.995413 -22.384499  skeletal_muscle_myocytes
# 299  -1.013401 -22.295118  skeletal_muscle_myocytes
#
# [300 rows x 3 columns]

# %%
unl_data = data.drop(columns='test_label')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Sam\Documents\met2vec\plot\_gmm_classifier.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sam/Documents/met2vec/plot/_gmm_classifier.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> unl_data = data.drop(columns='test_label')
#
# File c:\Users\Sam\Documents\met2vec\venv\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\Sam\Documents\met2vec\venv\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File c:\Users\Sam\Documents\met2vec\venv\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\Sam\Documents\met2vec\venv\Lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Users\Sam\Documents\met2vec\venv\Lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Users\Sam\Documents\met2vec\venv\Lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['test_label'] not found in axis"

# %%
im = plt.imshow(unl_data, vmin=0, vmax=1)
plt.colorbar(im, label='Accuracy', shrink=0.35, aspect=5)
plt.xticks([0,1,2], unl_data.columns, rotation=45)
plt.yticks(list(range(len(data))), data['test_label'])
# Out:
# ([<matplotlib.axis.YTick at 0x1ce359000d0>], [Text(0, 0, 'liver_hepatocytes')])

# %% [markdown]
# # Villarica

# %%
df_hc_agren = pd.read_csv('../data/plot_data/villarica/human_cells/regg10_d0.05_emb32_gmm_hc_al.csv')
df_hc_agren
# Out:
#    breast - glandular cells  appendix - lymphoid tissue  \
# 0                  0.000000                    0.000000
# 1                  0.009333                    0.010667
# 2                  0.026667                    0.000000
# 3                  0.000000                    0.000000
#
#    kidney - cells in glomeruli  cerebral cortex - neuropil  \
# 0                     0.002667                    0.028000
# 1                     0.002667                    0.029333
# 2                     0.054667                    0.000000
# 3                     0.090667                    0.000000
#
#    cerebral cortex - neuronal cells  hippocampus - glial cells  \
# 0                               0.0                   0.000000
# 1                               0.0                   0.032000
# 2                               0.0                   0.018667
# 3                               0.0                   0.000000
#
#    cerebellum - cells in molecular layer  adrenal gland - glandular cells  \
# 0                               0.041333                         0.001333
# 1                               0.000000                         0.000000
# 2                               0.001333                         0.001333
# 3                               0.000000                         0.033333
#
#    breast - myoepithelial cells  liver_hepatocytes  ...  \
# 0                      0.310667           0.033333  ...
# 1                      0.000000           0.005333  ...
# 2                      0.000000           0.000000  ...
# 3                      0.006667           0.000000  ...
#
#    esophagus - squamous epithelial cells  bone marrow - hematopoietic cells  \
# 0                               0.014667                           0.000000
# 1                               0.150667                           0.293333
# 2                               0.000000                           0.245333
# 3                               0.014667                           0.109333
#
#    gallbladder - glandular cells  heart muscle - myocytes  lung_macrophages  \
# 0                       0.074667                    0.000          0.058667
# 1                       0.013333                    0.000          0.052000
# 2                       0.000000                    0.012          0.000000
# 3                       0.009333                    0.000          0.097333
#
#    cervix, uterine - glandular cells  epididymis - glandular cells  \
# 0                           0.024000                      0.000000
# 1                           0.074667                      0.000000
# 2                           0.033333                      0.006667
# 3                           0.028000                      0.001333
#
#    cerebral cortex - endothelial cells  colon - endothelial cells  \
# 0                             0.000000                        0.0
# 1                             0.185333                        0.0
# 2                             0.000000                        0.0
# 3                             0.000000                        0.0
#
#                     test_label
# 0  liver cancer - patient 2280
# 1  liver cancer - patient 2177
# 2  liver cancer - patient 3196
# 3  liver cancer - patient 2556
#
# [4 rows x 33 columns]

# %%
df_hc_agren_unl = df_hc_agren.drop(columns='test_label')

# %%
fig, ax = plt.subplots(1,1, figsize=(18,4))

im = ax.imshow(df_hc_agren_unl, vmin=0, vmax=1)
plt.colorbar(im, label='Prediction Rate')

xlocs = range(df_hc_agren_unl.values.shape[1])
ylocs = range(len(df_hc_agren))

yticks = map(lambda s: s.replace('_', ' ').replace('2', ''), df_hc_agren['test_label'])

ax.set_xticks(xlocs, df_hc_agren_unl.columns, rotation=90)
ax.set_yticks(ylocs, yticks)
ax.set_ylabel("Test Scores")
ax.set_xlabel("")

fig.suptitle("GMM Prediction Rates (k=1)")
fig.tight_layout()

plt.show()
