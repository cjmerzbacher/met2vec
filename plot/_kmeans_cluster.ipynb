# %%
import pandas as pd
import matplotlib.pyplot as plt
import distinctipy as dpy

# %%
path = "../data/plot_data/human_cells/kmeans_emb32.csv"
df_kmeans = pd.read_csv(path)
df_tsne = pd.read_csv("../data/plot_data/human_cells/kmeans_emb32_tsne.csv")
df_kmeans
# Out:
#                                label  kmeans_cluster
# 0      cerebral cortex - glial cells              20
# 1      cerebral cortex - glial cells              20
# 2      cerebral cortex - glial cells              20
# 3      cerebral cortex - glial cells              20
# 4      cerebral cortex - glial cells              20
# ...                              ...             ...
# 15995            breast - adipocytes               4
# 15996            breast - adipocytes               4
# 15997            breast - adipocytes               4
# 15998            breast - adipocytes               4
# 15999            breast - adipocytes               4
#
# [16000 rows x 2 columns]

# %%
df_tsne
# Out:
#            tsne0      tsne1                          label
# 0       6.790986 -71.174840  cerebral cortex - glial cells
# 1       6.752455 -71.242065  cerebral cortex - glial cells
# 2       6.750712 -71.250370  cerebral cortex - glial cells
# 3       6.727443 -71.247240  cerebral cortex - glial cells
# 4       6.746139 -71.233240  cerebral cortex - glial cells
# ...          ...        ...                            ...
# 15995  26.226357 -18.737871            breast - adipocytes
# 15996  26.344946 -19.127111            breast - adipocytes
# 15997  26.451956 -19.328466            breast - adipocytes
# 15998  26.508846 -19.408869            breast - adipocytes
# 15999  26.362356 -18.949074            breast - adipocytes
#
# [16000 rows x 3 columns]

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,5))

kmeans_cols = dpy.get_colors(len(df_kmeans['kmeans_cluster'].unique()))
kmeans_c = [kmeans_cols[i] for i in df_kmeans["kmeans_cluster"]]

cell_types = list(df_kmeans['label'].unique())
cell_type_cols = dpy.get_colors(len(cell_types))
cell_type_c = [cell_type_cols[cell_types.index(cell)] for cell in df_kmeans['label']]

ax1.scatter(df_tsne["tsne0"], df_tsne["tsne1"], c=kmeans_c, s=0.5)
ax1.set_title("K-Means")

ax2.set_title("Cell Types")
ax2.scatter(df_tsne["tsne0"], df_tsne["tsne1"],c=cell_type_c, s=0.5)
