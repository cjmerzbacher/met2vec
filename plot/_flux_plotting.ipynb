# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Test

# %%
df_test = pd.read_csv("../data/plot_data/test.csv")
df_test
# Out:
#          emb0      emb1      emb2      emb3      emb4      emb5      emb6  \
# 0   -0.841629 -0.147177 -0.320218  0.151844  0.378105  0.584332 -0.396714
# 1    0.333697 -0.309053 -0.235952  0.424436  1.969839 -1.059843  0.735033
# 2    0.858755  0.709060  0.580807 -0.765278 -0.335531 -0.886575  0.745375
# 3    0.737901 -0.217611 -1.066260 -0.457392 -0.327976  0.242961  0.007290
# 4    0.229266 -1.000157  0.337734  1.277621 -0.362364 -0.364643 -0.050314
# ..        ...       ...       ...       ...       ...       ...       ...
# 295 -0.218324 -0.158093  0.585728 -0.315697  0.352742 -0.060137  0.000651
# 296  0.076091 -0.964213 -0.568811  0.327696 -0.291756  0.024189  0.159567
# 297 -0.658074 -0.462399 -0.867907 -1.153018 -0.665469  0.653510  0.360652
# 298 -0.338223 -0.490445 -0.432903  0.058214  0.493004 -0.603970  0.027460
# 299  0.915578  0.224636  0.227580 -0.141107 -0.491406 -0.360197  0.037481
#
#          emb7      emb8      emb9     emb10     emb11     emb12     emb13  \
# ...

# %%
sns.scatterplot(data=df_test, x=df_test.columns[0], y=df_test.columns[1], hue='label')
# Out:
# <Axes: xlabel='emb0', ylabel='emb1'>

# %% [markdown]
# # Real
