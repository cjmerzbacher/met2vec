# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("model/losses.csv")
df
# Out:
#        epoch        loss  reconstruction_loss  divergence_loss  \
# 0          0  1656.63040           1640.56580        16.064613
# 1          0  1381.20980           1365.15820        16.051666
# 2          0  1581.46220           1565.40500        16.057074
# 3          0  1663.01900           1646.95750        16.061470
# 4          0  1455.44580           1439.38300        16.062693
# ...      ...         ...                  ...              ...
# 14367     31   442.83080            416.77728        26.053524
# 14368     31   412.94180            386.98996        25.951841
# 14369     31   445.24650            419.07733        26.169159
# 14370     31   407.42920            382.27838        25.150808
# 14371     31   437.99603            411.74330        26.252760
#
#        stoicheometry_loss   test_loss  test_reconstruction_loss  \
# 0                     0.0  1595.65320                1579.59620
# 1                     0.0  1594.97610                1578.91880
# ...

# %%
df = df.groupby("epoch").mean()

# %%
plt.plot(df["loss"], label="Train $L$")
plt.plot(df["reconstruction_loss"], label="Train $L_D$")

plt.plot(df["test_loss"], label="Test $L$")

plt.legend()
