# %%
from cobra.io import read_sbml_model
from cobra.sampling import sample

# %%
liver_model = read_sbml_model("lung_macrophages.xml")
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# urn:miriam:9606 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# urn:miriam:obo.chebi:CHEBI:15389 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_m1 "(-)-trans-carveol">
# urn:miriam:obo.chebi:CHEBI:28261 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_m2 "(+)-alpha-pinene">
# urn:miriam:obo.chebi:CHEBI:28261 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# ...

# %%
# muscle_model = load_model("skeletal_muscle_myocytes.xml")
# lung_model = load_model("lung_macrophages.xml")

s = sample(liver_model, 100)
s.head()
# Out:
#    EX_m4117    EX_m4118  EX_m4119  EX_m4120    EX_m4121  EX_m4122  EX_m4123  \
# 0       0.0 -791.709577       0.0       0.0  993.843715       0.0       0.0
# 1       0.0 -792.119022       0.0       0.0  993.502121       0.0       0.0
# 2       0.0 -794.598887       0.0       0.0  985.940576       0.0       0.0
# 3       0.0 -793.562352       0.0       0.0  985.094813       0.0       0.0
# 4       0.0 -793.406726       0.0       0.0  984.268130       0.0       0.0
#
#      EX_m4124  EX_m4125   EX_m4126  ...    HMR_9458  HMR_9460   HMR_9682  \
# 0 -762.694669       0.0 -50.289805  ... -473.648643       0.0  50.289805
# 1 -762.357267       0.0 -49.841907  ... -473.620537       0.0  49.841907
# 2 -763.139374       0.0 -46.704797  ... -476.663993       0.0  46.704797
# 3 -761.092642       0.0 -44.488756  ... -476.295541       0.0  44.488756
# 4 -763.388532       0.0 -43.987209  ... -475.394833       0.0  43.987209
#
# ...

# %%
import pandas as pd

s.to_csv('liver_100.csv')

# %%
data = pd.read_csv('liver_100.csv')
vec = list(data.iloc[0])
vec[165]
